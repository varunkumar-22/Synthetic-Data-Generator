# %% [markdown]
# # Numeric Data Generation Example
#
# This notebook demonstrates generating numeric data using the structured data generator.

# %%
from structured_data_generator.core.generators import FINANCIAL_TEMPLATE, generate_from_template
import pandas as pd

# %%
# Generate financial data with numeric fields
data = generate_from_template(
    FINANCIAL_TEMPLATE,
    ["Transaction Info", "Loan Info"],
    count=50,
    seed=42
)

data.head()

# %%
# Display statistics
data.describe()
